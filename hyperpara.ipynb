# %%
import pandas as pd
from sklearn.datasets import load_iris

# %%
iris = load_iris()
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
df['target'] = iris.target

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %%
df['target'] = df['target'].apply(lambda x: iris.target_names[x])
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#         target
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(iris.data,iris.target,test_size=0.2,random_state=42)

# %%
from sklearn.svm import SVC

# %%
model = SVC(kernel = "rbf",C=30,gamma = 'auto')
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 1.0

# %%
from sklearn.model_selection import cross_val_score
import numpy as np

# %%
kernels = ['rbf','linear']
c = [10,20,30]
avg_score ={}
for kval in kernels:
    for cval in c:
        cv_scores = cross_val_score(SVC(kernel=kval,C=cval,gamma='auto'),iris.data,iris.target,cv=5)
        avg_score[kval+'_'+str(cval)] = np.average(cv_scores)

# %%
avg_score
# Out:
# {'rbf_10': 0.9800000000000001,
#  'rbf_20': 0.9666666666666668,
#  'rbf_30': 0.96,
#  'linear_10': 0.9733333333333334,
#  'linear_20': 0.9666666666666666,
#  'linear_30': 0.96}

# %%
from sklearn.model_selection import GridSearchCV

# %%
clf = GridSearchCV(SVC(gamma='auto'),{
    'C':[1,10,20],
    'kernel':['rbf','linear']
},cv=5,return_train_score=False)

# %%
clf.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(gamma='auto'),
#              param_grid={'C': [1, 10, 20], 'kernel': ['rbf', 'linear']})

# %%
clf.cv_results_
# Out:
# {'mean_fit_time': array([0.0009994 , 0.0008007 , 0.0008007 , 0.00080085, 0.00060134,
#         0.00040054]),
#  'std_fit_time': array([8.97163759e-07, 4.00356766e-04, 4.00352677e-04, 4.00424554e-04,
#         4.90992009e-04, 4.90563825e-04]),
#  'mean_score_time': array([0.00100064, 0.00079989, 0.00039954, 0.00020051, 0.00039954,
#         0.00059943]),
#  'std_score_time': array([1.11828226e-06, 3.99947319e-04, 4.89336843e-04, 4.01020050e-04,
#         4.89337819e-04, 4.89436177e-04]),
#  'param_C': masked_array(data=[1, 1, 10, 10, 20, 20],
#               mask=[False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'rbf', 'linear', 'rbf', 'linear'],
#               mask=[False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 1, 'kernel': 'rbf'},
#   {'C': 1, 'kernel': 'linear'},
#   {'C': 10, 'kernel': 'rbf'},
#   {'C': 10, 'kernel': 'linear'},
#   {'C': 20, 'kernel': 'rbf'},
#   {'C': 20, 'kernel': 'linear'}],
#  'split0_test_score': array([1.        , 1.        , 1.        , 1.        , 0.95833333,
#         0.95833333]),
#  'split1_test_score': array([0.95833333, 0.95833333, 0.95833333, 0.95833333, 0.95833333,
#         0.95833333]),
#  'split2_test_score': array([0.83333333, 0.875     , 0.83333333, 0.83333333, 0.83333333,
#         0.83333333]),
#  'split3_test_score': array([1.        , 1.        , 1.        , 0.95833333, 1.        ,
#         1.        ]),
#  'split4_test_score': array([0.95833333, 0.95833333, 1.        , 1.        , 1.        ,
#         1.        ]),
#  'mean_test_score': array([0.95      , 0.95833333, 0.95833333, 0.95      , 0.95      ,
#         0.95      ]),
#  'std_test_score': array([0.06123724, 0.04564355, 0.06454972, 0.06123724, 0.06123724,
#         0.06123724]),
#  'rank_test_score': array([3, 1, 1, 3, 3, 3])}

# %%
df1 = pd.DataFrame(clf.cv_results_)

# %%
df1
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       0.000999  8.971638e-07         0.001001        0.000001       1
# 1       0.000801  4.003568e-04         0.000800        0.000400       1
# 2       0.000801  4.003527e-04         0.000400        0.000489      10
# 3       0.000801  4.004246e-04         0.000201        0.000401      10
# 4       0.000601  4.909920e-04         0.000400        0.000489      20
# 5       0.000401  4.905638e-04         0.000599        0.000489      20
#
#   param_kernel                         params  split0_test_score  \
# 0          rbf      {'C': 1, 'kernel': 'rbf'}           1.000000
# 1       linear   {'C': 1, 'kernel': 'linear'}           1.000000
# 2          rbf     {'C': 10, 'kernel': 'rbf'}           1.000000
# 3       linear  {'C': 10, 'kernel': 'linear'}           1.000000
# 4          rbf     {'C': 20, 'kernel': 'rbf'}           0.958333
# 5       linear  {'C': 20, 'kernel': 'linear'}           0.958333
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.958333           0.833333           1.000000           0.958333
# 1           0.958333           0.875000           1.000000           0.958333
# 2           0.958333           0.833333           1.000000           1.000000
# 3           0.958333           0.833333           0.958333           1.000000
# 4           0.958333           0.833333           1.000000           1.000000
# 5           0.958333           0.833333           1.000000           1.000000
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.950000        0.061237                3
# 1         0.958333        0.045644                1
# 2         0.958333        0.064550                1
# 3         0.950000        0.061237                3
# 4         0.950000        0.061237                3
# 5         0.950000        0.061237                3

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
clf1 = RandomizedSearchCV(SVC(gamma='auto'),{
    'C':[1,10,20],
    'kernel':['rbf','linear']
},cv=5,return_train_score=False,n_iter=2)

# %%
clf1.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(gamma='auto'), n_iter=2,
#                    param_distributions={'C': [1, 10, 20],
#                                         'kernel': ['rbf', 'linear']})

# %%
df2 = pd.DataFrame(clf1.cv_results_)

# %%
df2
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_kernel  \
# 0       0.000600      0.000490         0.000622        0.000510          rbf
# 1       0.000732      0.000391         0.000270        0.000388          rbf
#
#   param_C                      params  split0_test_score  split1_test_score  \
# 0       1   {'kernel': 'rbf', 'C': 1}                1.0           0.958333
# 1      10  {'kernel': 'rbf', 'C': 10}                1.0           0.958333
#
#    split2_test_score  split3_test_score  split4_test_score  mean_test_score  \
# 0           0.833333                1.0           0.958333         0.950000
# 1           0.833333                1.0           1.000000         0.958333
#
#    std_test_score  rank_test_score
# 0        0.061237                2
# 1        0.064550                1

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# %%
model_params = {
    'svm':{
        'model':SVC(gamma='auto'),
        'params':{
            'C':[1,10,20],
            'kernel':['rbf','linear']
        }
    },
    'random_forest':{
        'model':RandomForestClassifier(),
        'params':{
            'n_estimators':[1,5,10]
        }
    },
    'LogisticRegression':{
        'model':LogisticRegression(solver='liblinear',multi_class='auto'),
        'params':{
            'C':[1,5,10],
        }
    }
}

# %%
scores = []
for model_name,mp in model_params.items():
    clf = GridSearchCV(mp['model'],mp['params'],cv=5,return_train_score=False)
    clf.fit(x_train,y_train)
    scores.append({
        'model':model_name,
        'bestS':clf.best_score_,
        'bestP':clf.best_params_
    })

# %%
scores
# Out:
# [{'model': 'svm',
#   'bestS': 0.9583333333333334,
#   'bestP': {'C': 1, 'kernel': 'linear'}},
#  {'model': 'random_forest', 'bestS': 0.95, 'bestP': {'n_estimators': 1}},
#  {'model': 'LogisticRegression',
#   'bestS': 0.9583333333333334,
#   'bestP': {'C': 10}}]

# %%
df3 = pd.DataFrame(scores,columns =['model','bestS','bestP'])

# %%
df3
# Out:
#                 model     bestS                         bestP
# 0                 svm  0.958333  {'C': 1, 'kernel': 'linear'}
# 1       random_forest  0.950000           {'n_estimators': 1}
# 2  LogisticRegression  0.958333                     {'C': 10}
